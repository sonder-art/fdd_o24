# %%
import numpy as np
import time
from joblib import Parallel, delayed
import math
import multiprocessing as mp

# Crear un array grande
arr = np.random.rand(10**7)

# For loop computacionalmente pesado
start = time.time()
result = []
for x in arr:
    result.append(x**2)
result = np.array(result)
end = time.time()

print(f"Tiempo con for loop: {end - start} segundos")
# Out:
# Tiempo con for loop: 1.141422986984253 segundos
# Process SpawnPoolWorker-118:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 389, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'compute_square_mp' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-119:
# Traceback (most recent call last):
# ...

# %%
# Usando numpy para vectorizar la operación
start = time.time()
result_np = arr**2
end = time.time()

print(f"Tiempo con numpy: {end - start} segundos")
# Out:
# Tiempo con numpy: 0.01968097686767578 segundos

# %%
# Definir función que hará la operación
def compute_square(x):
    return x**2

# Usar joblib para paralelizar el for loop
start = time.time()
result_joblib = Parallel(n_jobs=-1)(delayed(compute_square)(x) for x in arr)
end = time.time()

print(f"Tiempo con joblib: {end - start} segundos")
# Out:
# Tiempo con joblib: 35.479668855667114 segundos

# %%
# Definir función para calcular el cuadrado
def compute_square_mp(x):
    return x**2

# Usar multiprocessing para paralelizar
if __name__ == '__main__':
    start = time.time()
    pool = mp.Pool(mp.cpu_count())
    result_mp = pool.map(compute_square_mp, arr)
    pool.close()
    end = time.time()

    print(f"Tiempo con multiprocessing: {end - start} segundos")
# Out:
# Process SpawnPoolWorker-131:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 389, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'compute_square_mp' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-136:
# Traceback (most recent call last):
# ...
