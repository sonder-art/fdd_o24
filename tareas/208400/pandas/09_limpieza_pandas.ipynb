# %% [markdown]
# # Prediccion de Default en Prestamos

# %% [markdown]
# Para este proyecto utilizaremos un sample de los datos de Lending Club. La idea es predecir si cierto usuario cometera Default basado en informacion que la plataforma recolecta. Esto nos ayudara a mejorar la metodologia/pipeline de prestamo.

# %% [markdown]
# # Descripcion

# %% [markdown]
# Contiene los prestamos de esta plataforma:
#
#     periodo 2007-2017Q3.
#     887mil observaciones, sample de 100mil
#     150 variables
#     Target: loan status

# %% [markdown]
# # Objetivo

# %% [markdown]
# Realizar un ETL y un EDA

# %% [markdown]
# ## ETL

# %% [markdown]
# 0. Limpia los datos de tal manera que al final del ETL queden en formato `tidy`.
# 1. Asegurate de cargar y leer los datos
# 2. Crea una tabla donde se guarde el nombre de la columna y el tipo de dato: (`column_name`,   `type`).
# 3. Asegurate de pensar cual es el tipo de dato correcto. Porque elejiste strig/object o float o int?. No hay respuestas incorrectas como tal, pero tienes que justificar tu decision.
# 4. Maneja missings o nans de la manera adecuada. Justifica cada decision

# %% [markdown]
# ## EDA

# %% [markdown]
# 0. Preparar lo datos para un pipeline de datos
# 1. Quitar columnas inservibles
# 2. Imputar valores
# 3. Mantener replicabildiad y reproducibilidad

# %% [markdown]
# **No olvides anotar tus justificaciones en celdas para recordar cuando te toque explicarlo.** Puedes agregar el numero de celdas que necesites para poner tu explicacion y el codigo, solo manten la estructura.

# %% [markdown]
# # ETL

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Vas a obtener 2 errores, solucionalo con los visto en clase.
# Tip: Se arreglan con argumentos adicionales de la funcion `read_csv`
# Documentacion: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
# loans = pd.read_csv('https://github.com/sonder-art/fdd_prim_2023/blob/main/codigo/pandas/LoansData_sample.csv.gz?raw=true')

# loans

loans = pd.read_csv(
    'https://github.com/sonder-art/fdd_prim_2023/blob/main/codigo/pandas/LoansData_sample.csv.gz?raw=true',
    compression='gzip',
    encoding='utf-8'
)

loans.to_csv('loans.csv')
# Out:
# /tmp/ipykernel_7375/3955335309.py:5: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   loans = pd.read_csv(

# %% [markdown]
# ## Tabla (column_name, type)

# %% [markdown]
# Revisa el metodo pd.DataFrame.dtypes. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html

# %%
# column_types =
columns = loans.columns.to_list()
print(columns)

loans.dtypes.unique()
# Out:
# ['Unnamed: 0', 'id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_length', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'disbursement_method', 'debt_settlement_flag', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term']
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %% [markdown]
# ## Cargar descripcion de columnas

# %% [markdown]
# La siguiente tabla tiene una descripcion del significado de cada columna

# %%
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/gitpod/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
datos_dict = pd.read_excel(
    'https://resources.lendingclub.com/LCDataDictionary.xlsx')
datos_dict.columns = ['feature', 'description']

# %%
datos_dict
# Out:
#                    feature                                        description
# 0           acc_now_delinq  The number of accounts on which the borrower i...
# 1     acc_open_past_24mths         Number of trades opened in past 24 months.
# 2               addr_state  The state provided by the borrower in the loan...
# 3                 all_util              Balance to credit limit on all trades
# 4               annual_inc  The self-reported annual income provided by th...
# ..                     ...                                                ...
# 148      settlement_amount  The loan amount that the borrower has agreed t...
# 149  settlement_percentage  The settlement amount as a percentage of the p...
# 150        settlement_term  The number of months that the borrower will be...
# 151                    NaN                                                NaN
# 152                    NaN  * Employer Title replaces Employer Name for al...
#
# [153 rows x 2 columns]

# %% [markdown]
# ### Pickle

# %% [markdown]
# Crea codigo para **guardar** y **cargar** el DataFrame de `datos_dict` creada en las celdas anteriores en formato **pickle**

# %%
# COdigo guardar
# Guardar el DataFrame en formato pickle
datos_dict.to_pickle('datos_dict.pkl')

# %%
# Codigo para cargar
# Cargar el DataFrame desde el archivo pickle
datos_dict_cargado = pd.read_pickle('datos_dict.pkl')

# %% [markdown]
# ## Tipos de Datos

# %% [markdown]
# Realiza las transformaciones o casteos (casting) que creas necesarios a tus datos de tal manera que el typo de dato sea adecuado. Al terminar recrea la tabla `column_types` con los nuevos tipos.

# %% [markdown]
# No olvides anotar tus justificaciones para recordar cuando te toque explicarlo.

# %%
loans.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %%
# Manejos de tipos 1
# Tu codigo aqui

int64_columns = [col for col in loans.columns if loans[col].dtype == 'int64']

def change_cast_to_int32(df, columns):
    int32_min, int32_max = -2**31, 2**31 - 1  # Range of int32
    
    for col in columns:
        if col not in df.columns:
            print(f"Column '{col}' does not exist in the DataFrame.")
            continue

        # Check if column is numeric
        if not pd.api.types.is_numeric_dtype(df[col]):
            print(f"Column '{col}' is not numeric, skipping.")
            continue

        # Check for NaNs and analyze range
        has_nan = df[col].isna().any()
        min_val = df[col].min()
        max_val = df[col].max()

        print(f"\nAnalyzing column '{col}':")
        print(f"  - Min value: {min_val}")
        print(f"  - Max value: {max_val}")
        print(f"  - Contains NaNs: {'Yes' if has_nan else 'No'}")

        # Evaluate if casting to int32 is safe
        if has_nan:
            print(f"  - Column '{col}' has NaN values, conversion to int32 will not be possible without handling them.")
        elif min_val >= int32_min and max_val <= int32_max:
            print(f"  - Column '{col}' is within int32 range. It can be safely cast to int32.")
            # Optional: Cast to int32 if suitable
            df[col] = df[col].astype('int32')
            print(f"  - Column '{col}' has been cast to int32.")
        else:
            print(f"  - Column '{col}' has values outside int32 range. Conversion to int32 is not safe.")

# %%
loans[int64_columns]
# Out:
#        Unnamed: 0        id
# 0               0  38098114
# 1               1  36805548
# 2               2  37842129
# 3               3  37612354
# 4               4  37662224
# ...           ...       ...
# 99995       99995  22454240
# 99996       99996  11396920
# 99997       99997   8556176
# 99998       99998  24023408
# 99999       99999  24023398
#
# [100000 rows x 2 columns]

# %%
change_cast_to_int32(loans, int64_columns)
# Out:
# Analyzing column 'Unnamed: 0':
#   - Min value: 0
#   - Max value: 99999
#   - Contains NaNs: No
#   - Column 'Unnamed: 0' is within int32 range. It can be safely cast to int32.
#   - Column 'Unnamed: 0' has been cast to int32.
#
# Analyzing column 'id':
#   - Min value: 57167
#   - Max value: 38098114
#   - Contains NaNs: No
#   - Column 'id' is within int32 range. It can be safely cast to int32.
#   - Column 'id' has been cast to int32.

# %%
# Manejos de tipos 2
# Tu codigo aqui

float64_columns = [col for col in loans.columns if loans[col].dtype == 'float64']

def cast_float32(df, columns):
    float32_min, float32_max = np.finfo(np.float32).min, np.finfo(np.float32).max  # Range of float32
    
    for col in columns:
        if col not in df.columns:
            print(f"Column '{col}' does not exist in the DataFrame.")
            continue

        # Check if column is of type float64
        if df[col].dtype != 'float64':
            print(f"Column '{col}' is not of type float64, skipping.")
            continue

        # Check for NaNs and analyze range
        has_nan = df[col].isna().any()
        min_val = df[col].min()
        max_val = df[col].max()

        print(f"\nAnalyzing column '{col}':")
        print(f"  - Min value: {min_val}")
        print(f"  - Max value: {max_val}")
        print(f"  - Contains NaNs: {'Yes' if has_nan else 'No'}")

        # Evaluate if casting to float32 is safe
        if min_val >= float32_min and max_val <= float32_max:
            print(f"  - Column '{col}' is within float32 range and can be safely cast to float32.")
            # Optional: Cast to float32 if suitable
            df[col] = df[col].astype('float32')
            print(f"  - Column '{col}' has been cast to float32.")
        else:
            print(f"  - Column '{col}' has values outside the float32 range. Conversion to float32 is not safe.")

# %%
loans[float64_columns]
# Out:
#        member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# 0            NaN    15000.0      15000.0          15000.0     12.39
# 1            NaN    10400.0      10400.0          10400.0      6.99
# 2            NaN    21425.0      21425.0          21425.0     15.59
# 3            NaN    12800.0      12800.0          12800.0     17.14
# 4            NaN     7650.0       7650.0           7650.0     13.66
# ...          ...        ...          ...              ...       ...
# 99995        NaN     8400.0       8400.0           8400.0      9.17
# 99996        NaN    10000.0      10000.0          10000.0     12.99
# 99997        NaN    30000.0      30000.0          30000.0     20.99
# 99998        NaN     8475.0       8475.0           8475.0     24.99
# 99999        NaN    25000.0      25000.0          25000.0     10.15
#
#        installment  annual_inc    dti  delinq_2yrs  fico_range_low  ...  \
# 0           336.64     78000.0  12.03          0.0           750.0  ...
# 1           321.08     58000.0  14.92          0.0           710.0  ...
# 2           516.36     63800.0  18.49          0.0           685.0  ...
# 3           319.08    125000.0   8.31          1.0           665.0  ...
# 4           260.20     50000.0  34.81          0.0           685.0  ...
# ...            ...         ...    ...          ...             ...  ...
# 99995       267.79     91000.0   7.78          1.0           705.0  ...
# 99996       336.90     53133.0  15.25          0.0           690.0  ...
# 99997       811.44     78000.0  23.75          0.0           665.0  ...
# 99998       336.92     52000.0  17.61          2.0           660.0  ...
# 99999       808.45     60000.0  27.82          0.0           730.0  ...
#
#        deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# 0                NaN              NaN              NaN           NaN
# 1                NaN              NaN              NaN           NaN
# 2                NaN              NaN              NaN           NaN
# 3                NaN              NaN              NaN           NaN
# 4                NaN              NaN              NaN           NaN
# ...              ...              ...              ...           ...
# 99995            NaN              NaN              NaN           NaN
# 99996            NaN              NaN              NaN           NaN
# 99997            NaN              NaN              NaN           NaN
# 99998            NaN              NaN              NaN           NaN
# 99999            NaN              NaN              NaN           NaN
#
#        orig_projected_additional_accrued_interest  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 99995                                         NaN
# 99996                                         NaN
# 99997                                         NaN
# 99998                                         NaN
# 99999                                         NaN
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 99995                             NaN                           NaN
# 99996                             NaN                           NaN
# 99997                             NaN                           NaN
# 99998                             NaN                           NaN
# 99999                             NaN                           NaN
#
#        settlement_amount  settlement_percentage  settlement_term
# 0                    NaN                    NaN              NaN
# 1                    NaN                    NaN              NaN
# 2                    NaN                    NaN              NaN
# 3                    NaN                    NaN              NaN
# 4                    NaN                    NaN              NaN
# ...                  ...                    ...              ...
# 99995                NaN                    NaN              NaN
# 99996                NaN                    NaN              NaN
# 99997                NaN                    NaN              NaN
# 99998                NaN                    NaN              NaN
# 99999                NaN                    NaN              NaN
#
# [100000 rows x 115 columns]

# %%
cast_float32(loans, float64_columns)
# Out:
# Analyzing column 'member_id':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'member_id' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'loan_amnt':
#   - Min value: 1000.0
#   - Max value: 35000.0
#   - Contains NaNs: No
#   - Column 'loan_amnt' is within float32 range and can be safely cast to float32.
#   - Column 'loan_amnt' has been cast to float32.
#
# Analyzing column 'funded_amnt':
#   - Min value: 1000.0
#   - Max value: 35000.0
#   - Contains NaNs: No
#   - Column 'funded_amnt' is within float32 range and can be safely cast to float32.
#   - Column 'funded_amnt' has been cast to float32.
#
# Analyzing column 'funded_amnt_inv':
#   - Min value: 1000.0
#   - Max value: 35000.0
#   - Contains NaNs: No
#   - Column 'funded_amnt_inv' is within float32 range and can be safely cast to float32.
#   - Column 'funded_amnt_inv' has been cast to float32.
#
# Analyzing column 'int_rate':
#   - Min value: 6.0
#   - Max value: 26.06
#   - Contains NaNs: No
#   - Column 'int_rate' is within float32 range and can be safely cast to float32.
#   - Column 'int_rate' has been cast to float32.
#
# Analyzing column 'installment':
#   - Min value: 30.42
#   - Max value: 1408.13
#   - Contains NaNs: No
#   - Column 'installment' is within float32 range and can be safely cast to float32.
#   - Column 'installment' has been cast to float32.
#
# Analyzing column 'annual_inc':
#   - Min value: 4000.0
#   - Max value: 7500000.0
#   - Contains NaNs: No
#   - Column 'annual_inc' is within float32 range and can be safely cast to float32.
#   - Column 'annual_inc' has been cast to float32.
#
# Analyzing column 'dti':
#   - Min value: 0.0
#   - Max value: 39.99
#   - Contains NaNs: No
#   - Column 'dti' is within float32 range and can be safely cast to float32.
#   - Column 'dti' has been cast to float32.
#
# Analyzing column 'delinq_2yrs':
#   - Min value: 0.0
#   - Max value: 22.0
#   - Contains NaNs: No
#   - Column 'delinq_2yrs' is within float32 range and can be safely cast to float32.
#   - Column 'delinq_2yrs' has been cast to float32.
#
# Analyzing column 'fico_range_low':
#   - Min value: 660.0
#   - Max value: 845.0
#   - Contains NaNs: No
#   - Column 'fico_range_low' is within float32 range and can be safely cast to float32.
#   - Column 'fico_range_low' has been cast to float32.
#
# Analyzing column 'fico_range_high':
#   - Min value: 664.0
#   - Max value: 850.0
#   - Contains NaNs: No
#   - Column 'fico_range_high' is within float32 range and can be safely cast to float32.
#   - Column 'fico_range_high' has been cast to float32.
#
# Analyzing column 'inq_last_6mths':
#   - Min value: 0.0
#   - Max value: 6.0
#   - Contains NaNs: No
#   - Column 'inq_last_6mths' is within float32 range and can be safely cast to float32.
#   - Column 'inq_last_6mths' has been cast to float32.
#
# Analyzing column 'mths_since_last_delinq':
#   - Min value: 0.0
#   - Max value: 141.0
#   - Contains NaNs: Yes
#   - Column 'mths_since_last_delinq' is within float32 range and can be safely cast to float32.
#   - Column 'mths_since_last_delinq' has been cast to float32.
#
# Analyzing column 'mths_since_last_record':
#   - Min value: 0.0
#   - Max value: 120.0
#   - Contains NaNs: Yes
#   - Column 'mths_since_last_record' is within float32 range and can be safely cast to float32.
#   - Column 'mths_since_last_record' has been cast to float32.
#
# Analyzing column 'open_acc':
#   - Min value: 1.0
#   - Max value: 84.0
#   - Contains NaNs: No
#   - Column 'open_acc' is within float32 range and can be safely cast to float32.
#   - Column 'open_acc' has been cast to float32.
#
# Analyzing column 'pub_rec':
#   - Min value: 0.0
#   - Max value: 19.0
#   - Contains NaNs: No
#   - Column 'pub_rec' is within float32 range and can be safely cast to float32.
#   - Column 'pub_rec' has been cast to float32.
#
# Analyzing column 'revol_bal':
#   - Min value: 0.0
#   - Max value: 2560703.0
#   - Contains NaNs: No
#   - Column 'revol_bal' is within float32 range and can be safely cast to float32.
#   - Column 'revol_bal' has been cast to float32.
#
# Analyzing column 'revol_util':
#   - Min value: 0.0
#   - Max value: 180.3
#   - Contains NaNs: Yes
#   - Column 'revol_util' is within float32 range and can be safely cast to float32.
#   - Column 'revol_util' has been cast to float32.
#
# Analyzing column 'total_acc':
#   - Min value: 3.0
#   - Max value: 156.0
#   - Contains NaNs: No
#   - Column 'total_acc' is within float32 range and can be safely cast to float32.
#   - Column 'total_acc' has been cast to float32.
#
# Analyzing column 'out_prncp':
#   - Min value: 0.0
#   - Max value: 21209.06
#   - Contains NaNs: No
#   - Column 'out_prncp' is within float32 range and can be safely cast to float32.
#   - Column 'out_prncp' has been cast to float32.
#
# Analyzing column 'out_prncp_inv':
#   - Min value: 0.0
#   - Max value: 21209.06
#   - Contains NaNs: No
#   - Column 'out_prncp_inv' is within float32 range and can be safely cast to float32.
#   - Column 'out_prncp_inv' has been cast to float32.
#
# Analyzing column 'total_pymnt':
#   - Min value: 0.0
#   - Max value: 56833.4079008709
#   - Contains NaNs: No
#   - Column 'total_pymnt' is within float32 range and can be safely cast to float32.
#   - Column 'total_pymnt' has been cast to float32.
#
# Analyzing column 'total_pymnt_inv':
#   - Min value: 0.0
#   - Max value: 56833.41
#   - Contains NaNs: No
#   - Column 'total_pymnt_inv' is within float32 range and can be safely cast to float32.
#   - Column 'total_pymnt_inv' has been cast to float32.
#
# Analyzing column 'total_rec_prncp':
#   - Min value: 0.0
#   - Max value: 35000.0
#   - Contains NaNs: No
#   - Column 'total_rec_prncp' is within float32 range and can be safely cast to float32.
#   - Column 'total_rec_prncp' has been cast to float32.
#
# Analyzing column 'total_rec_int':
#   - Min value: 0.0
#   - Max value: 23851.97
#   - Contains NaNs: No
#   - Column 'total_rec_int' is within float32 range and can be safely cast to float32.
#   - Column 'total_rec_int' has been cast to float32.
#
# Analyzing column 'total_rec_late_fee':
#   - Min value: 0.0
#   - Max value: 338.46
#   - Contains NaNs: No
#   - Column 'total_rec_late_fee' is within float32 range and can be safely cast to float32.
#   - Column 'total_rec_late_fee' has been cast to float32.
#
# Analyzing column 'recoveries':
#   - Min value: 0.0
#   - Max value: 29923.86
#   - Contains NaNs: No
#   - Column 'recoveries' is within float32 range and can be safely cast to float32.
#   - Column 'recoveries' has been cast to float32.
#
# Analyzing column 'collection_recovery_fee':
#   - Min value: 0.0
#   - Max value: 5386.2930000000015
#   - Contains NaNs: No
#   - Column 'collection_recovery_fee' is within float32 range and can be safely cast to float32.
#   - Column 'collection_recovery_fee' has been cast to float32.
#
# Analyzing column 'last_pymnt_amnt':
#   - Min value: 0.0
#   - Max value: 36234.44
#   - Contains NaNs: No
#   - Column 'last_pymnt_amnt' is within float32 range and can be safely cast to float32.
#   - Column 'last_pymnt_amnt' has been cast to float32.
#
# Analyzing column 'last_fico_range_high':
#   - Min value: 0.0
#   - Max value: 850.0
#   - Contains NaNs: No
#   - Column 'last_fico_range_high' is within float32 range and can be safely cast to float32.
#   - Column 'last_fico_range_high' has been cast to float32.
#
# Analyzing column 'last_fico_range_low':
#   - Min value: 0.0
#   - Max value: 845.0
#   - Contains NaNs: No
#   - Column 'last_fico_range_low' is within float32 range and can be safely cast to float32.
#   - Column 'last_fico_range_low' has been cast to float32.
#
# Analyzing column 'collections_12_mths_ex_med':
#   - Min value: 0.0
#   - Max value: 20.0
#   - Contains NaNs: No
#   - Column 'collections_12_mths_ex_med' is within float32 range and can be safely cast to float32.
#   - Column 'collections_12_mths_ex_med' has been cast to float32.
#
# Analyzing column 'mths_since_last_major_derog':
#   - Min value: 0.0
#   - Max value: 169.0
#   - Contains NaNs: Yes
#   - Column 'mths_since_last_major_derog' is within float32 range and can be safely cast to float32.
#   - Column 'mths_since_last_major_derog' has been cast to float32.
#
# Analyzing column 'policy_code':
#   - Min value: 1.0
#   - Max value: 1.0
#   - Contains NaNs: No
#   - Column 'policy_code' is within float32 range and can be safely cast to float32.
#   - Column 'policy_code' has been cast to float32.
#
# Analyzing column 'annual_inc_joint':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'annual_inc_joint' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'dti_joint':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'dti_joint' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'verification_status_joint':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'verification_status_joint' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'acc_now_delinq':
#   - Min value: 0.0
#   - Max value: 4.0
#   - Contains NaNs: No
#   - Column 'acc_now_delinq' is within float32 range and can be safely cast to float32.
#   - Column 'acc_now_delinq' has been cast to float32.
#
# Analyzing column 'tot_coll_amt':
#   - Min value: 0.0
#   - Max value: 296368.0
#   - Contains NaNs: No
#   - Column 'tot_coll_amt' is within float32 range and can be safely cast to float32.
#   - Column 'tot_coll_amt' has been cast to float32.
#
# Analyzing column 'tot_cur_bal':
#   - Min value: 0.0
#   - Max value: 4026405.0
#   - Contains NaNs: No
#   - Column 'tot_cur_bal' is within float32 range and can be safely cast to float32.
#   - Column 'tot_cur_bal' has been cast to float32.
#
# Analyzing column 'open_acc_6m':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'open_acc_6m' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'open_act_il':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'open_act_il' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'open_il_12m':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'open_il_12m' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'open_il_24m':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'open_il_24m' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'mths_since_rcnt_il':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'mths_since_rcnt_il' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'total_bal_il':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'total_bal_il' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'il_util':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'il_util' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'open_rv_12m':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'open_rv_12m' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'open_rv_24m':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'open_rv_24m' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'max_bal_bc':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'max_bal_bc' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'all_util':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'all_util' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'total_rev_hi_lim':
#   - Min value: 0.0
#   - Max value: 9999999.0
#   - Contains NaNs: No
#   - Column 'total_rev_hi_lim' is within float32 range and can be safely cast to float32.
#   - Column 'total_rev_hi_lim' has been cast to float32.
#
# Analyzing column 'inq_fi':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'inq_fi' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'total_cu_tl':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'total_cu_tl' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'inq_last_12m':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'inq_last_12m' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'acc_open_past_24mths':
#   - Min value: 0.0
#   - Max value: 53.0
#   - Contains NaNs: No
#   - Column 'acc_open_past_24mths' is within float32 range and can be safely cast to float32.
#   - Column 'acc_open_past_24mths' has been cast to float32.
#
# Analyzing column 'avg_cur_bal':
#   - Min value: 0.0
#   - Max value: 447433.0
#   - Contains NaNs: No
#   - Column 'avg_cur_bal' is within float32 range and can be safely cast to float32.
#   - Column 'avg_cur_bal' has been cast to float32.
#
# Analyzing column 'bc_open_to_buy':
#   - Min value: 0.0
#   - Max value: 249625.0
#   - Contains NaNs: Yes
#   - Column 'bc_open_to_buy' is within float32 range and can be safely cast to float32.
#   - Column 'bc_open_to_buy' has been cast to float32.
#
# Analyzing column 'bc_util':
#   - Min value: 0.0
#   - Max value: 255.2
#   - Contains NaNs: Yes
#   - Column 'bc_util' is within float32 range and can be safely cast to float32.
#   - Column 'bc_util' has been cast to float32.
#
# Analyzing column 'chargeoff_within_12_mths':
#   - Min value: 0.0
#   - Max value: 4.0
#   - Contains NaNs: No
#   - Column 'chargeoff_within_12_mths' is within float32 range and can be safely cast to float32.
#   - Column 'chargeoff_within_12_mths' has been cast to float32.
#
# Analyzing column 'delinq_amnt':
#   - Min value: 0.0
#   - Max value: 65000.0
#   - Contains NaNs: No
#   - Column 'delinq_amnt' is within float32 range and can be safely cast to float32.
#   - Column 'delinq_amnt' has been cast to float32.
#
# Analyzing column 'mo_sin_old_il_acct':
#   - Min value: 0.0
#   - Max value: 561.0
#   - Contains NaNs: Yes
#   - Column 'mo_sin_old_il_acct' is within float32 range and can be safely cast to float32.
#   - Column 'mo_sin_old_il_acct' has been cast to float32.
#
# Analyzing column 'mo_sin_old_rev_tl_op':
#   - Min value: 3.0
#   - Max value: 818.0
#   - Contains NaNs: No
#   - Column 'mo_sin_old_rev_tl_op' is within float32 range and can be safely cast to float32.
#   - Column 'mo_sin_old_rev_tl_op' has been cast to float32.
#
# Analyzing column 'mo_sin_rcnt_rev_tl_op':
#   - Min value: 0.0
#   - Max value: 372.0
#   - Contains NaNs: No
#   - Column 'mo_sin_rcnt_rev_tl_op' is within float32 range and can be safely cast to float32.
#   - Column 'mo_sin_rcnt_rev_tl_op' has been cast to float32.
#
# Analyzing column 'mo_sin_rcnt_tl':
#   - Min value: 0.0
#   - Max value: 194.0
#   - Contains NaNs: No
#   - Column 'mo_sin_rcnt_tl' is within float32 range and can be safely cast to float32.
#   - Column 'mo_sin_rcnt_tl' has been cast to float32.
#
# Analyzing column 'mort_acc':
#   - Min value: 0.0
#   - Max value: 36.0
#   - Contains NaNs: No
#   - Column 'mort_acc' is within float32 range and can be safely cast to float32.
#   - Column 'mort_acc' has been cast to float32.
#
# Analyzing column 'mths_since_recent_bc':
#   - Min value: 0.0
#   - Max value: 616.0
#   - Contains NaNs: Yes
#   - Column 'mths_since_recent_bc' is within float32 range and can be safely cast to float32.
#   - Column 'mths_since_recent_bc' has been cast to float32.
#
# Analyzing column 'mths_since_recent_bc_dlq':
#   - Min value: 0.0
#   - Max value: 154.0
#   - Contains NaNs: Yes
#   - Column 'mths_since_recent_bc_dlq' is within float32 range and can be safely cast to float32.
#   - Column 'mths_since_recent_bc_dlq' has been cast to float32.
#
# Analyzing column 'mths_since_recent_inq':
#   - Min value: 0.0
#   - Max value: 25.0
#   - Contains NaNs: Yes
#   - Column 'mths_since_recent_inq' is within float32 range and can be safely cast to float32.
#   - Column 'mths_since_recent_inq' has been cast to float32.
#
# Analyzing column 'mths_since_recent_revol_delinq':
#   - Min value: 0.0
#   - Max value: 154.0
#   - Contains NaNs: Yes
#   - Column 'mths_since_recent_revol_delinq' is within float32 range and can be safely cast to float32.
#   - Column 'mths_since_recent_revol_delinq' has been cast to float32.
#
# Analyzing column 'num_accts_ever_120_pd':
#   - Min value: 0.0
#   - Max value: 33.0
#   - Contains NaNs: No
#   - Column 'num_accts_ever_120_pd' is within float32 range and can be safely cast to float32.
#   - Column 'num_accts_ever_120_pd' has been cast to float32.
#
# Analyzing column 'num_actv_bc_tl':
#   - Min value: 0.0
#   - Max value: 26.0
#   - Contains NaNs: No
#   - Column 'num_actv_bc_tl' is within float32 range and can be safely cast to float32.
#   - Column 'num_actv_bc_tl' has been cast to float32.
#
# Analyzing column 'num_actv_rev_tl':
#   - Min value: 0.0
#   - Max value: 38.0
#   - Contains NaNs: No
#   - Column 'num_actv_rev_tl' is within float32 range and can be safely cast to float32.
#   - Column 'num_actv_rev_tl' has been cast to float32.
#
# Analyzing column 'num_bc_sats':
#   - Min value: 0.0
#   - Max value: 35.0
#   - Contains NaNs: No
#   - Column 'num_bc_sats' is within float32 range and can be safely cast to float32.
#   - Column 'num_bc_sats' has been cast to float32.
#
# Analyzing column 'num_bc_tl':
#   - Min value: 0.0
#   - Max value: 58.0
#   - Contains NaNs: No
#   - Column 'num_bc_tl' is within float32 range and can be safely cast to float32.
#   - Column 'num_bc_tl' has been cast to float32.
#
# Analyzing column 'num_il_tl':
#   - Min value: 0.0
#   - Max value: 150.0
#   - Contains NaNs: No
#   - Column 'num_il_tl' is within float32 range and can be safely cast to float32.
#   - Column 'num_il_tl' has been cast to float32.
#
# Analyzing column 'num_op_rev_tl':
#   - Min value: 0.0
#   - Max value: 62.0
#   - Contains NaNs: No
#   - Column 'num_op_rev_tl' is within float32 range and can be safely cast to float32.
#   - Column 'num_op_rev_tl' has been cast to float32.
#
# Analyzing column 'num_rev_accts':
#   - Min value: 2.0
#   - Max value: 105.0
#   - Contains NaNs: No
#   - Column 'num_rev_accts' is within float32 range and can be safely cast to float32.
#   - Column 'num_rev_accts' has been cast to float32.
#
# Analyzing column 'num_rev_tl_bal_gt_0':
#   - Min value: 0.0
#   - Max value: 38.0
#   - Contains NaNs: No
#   - Column 'num_rev_tl_bal_gt_0' is within float32 range and can be safely cast to float32.
#   - Column 'num_rev_tl_bal_gt_0' has been cast to float32.
#
# Analyzing column 'num_sats':
#   - Min value: 1.0
#   - Max value: 84.0
#   - Contains NaNs: No
#   - Column 'num_sats' is within float32 range and can be safely cast to float32.
#   - Column 'num_sats' has been cast to float32.
#
# Analyzing column 'num_tl_120dpd_2m':
#   - Min value: 0.0
#   - Max value: 2.0
#   - Contains NaNs: Yes
#   - Column 'num_tl_120dpd_2m' is within float32 range and can be safely cast to float32.
#   - Column 'num_tl_120dpd_2m' has been cast to float32.
#
# Analyzing column 'num_tl_30dpd':
#   - Min value: 0.0
#   - Max value: 4.0
#   - Contains NaNs: No
#   - Column 'num_tl_30dpd' is within float32 range and can be safely cast to float32.
#   - Column 'num_tl_30dpd' has been cast to float32.
#
# Analyzing column 'num_tl_90g_dpd_24m':
#   - Min value: 0.0
#   - Max value: 22.0
#   - Contains NaNs: No
#   - Column 'num_tl_90g_dpd_24m' is within float32 range and can be safely cast to float32.
#   - Column 'num_tl_90g_dpd_24m' has been cast to float32.
#
# Analyzing column 'num_tl_op_past_12m':
#   - Min value: 0.0
#   - Max value: 26.0
#   - Contains NaNs: No
#   - Column 'num_tl_op_past_12m' is within float32 range and can be safely cast to float32.
#   - Column 'num_tl_op_past_12m' has been cast to float32.
#
# Analyzing column 'pct_tl_nvr_dlq':
#   - Min value: 16.7
#   - Max value: 100.0
#   - Contains NaNs: No
#   - Column 'pct_tl_nvr_dlq' is within float32 range and can be safely cast to float32.
#   - Column 'pct_tl_nvr_dlq' has been cast to float32.
#
# Analyzing column 'percent_bc_gt_75':
#   - Min value: 0.0
#   - Max value: 100.0
#   - Contains NaNs: Yes
#   - Column 'percent_bc_gt_75' is within float32 range and can be safely cast to float32.
#   - Column 'percent_bc_gt_75' has been cast to float32.
#
# Analyzing column 'pub_rec_bankruptcies':
#   - Min value: 0.0
#   - Max value: 12.0
#   - Contains NaNs: No
#   - Column 'pub_rec_bankruptcies' is within float32 range and can be safely cast to float32.
#   - Column 'pub_rec_bankruptcies' has been cast to float32.
#
# Analyzing column 'tax_liens':
#   - Min value: 0.0
#   - Max value: 18.0
#   - Contains NaNs: No
#   - Column 'tax_liens' is within float32 range and can be safely cast to float32.
#   - Column 'tax_liens' has been cast to float32.
#
# Analyzing column 'tot_hi_cred_lim':
#   - Min value: 1800.0
#   - Max value: 9999999.0
#   - Contains NaNs: No
#   - Column 'tot_hi_cred_lim' is within float32 range and can be safely cast to float32.
#   - Column 'tot_hi_cred_lim' has been cast to float32.
#
# Analyzing column 'total_bal_ex_mort':
#   - Min value: 0.0
#   - Max value: 2688920.0
#   - Contains NaNs: No
#   - Column 'total_bal_ex_mort' is within float32 range and can be safely cast to float32.
#   - Column 'total_bal_ex_mort' has been cast to float32.
#
# Analyzing column 'total_bc_limit':
#   - Min value: 0.0
#   - Max value: 456200.0
#   - Contains NaNs: No
#   - Column 'total_bc_limit' is within float32 range and can be safely cast to float32.
#   - Column 'total_bc_limit' has been cast to float32.
#
# Analyzing column 'total_il_high_credit_limit':
#   - Min value: 0.0
#   - Max value: 876963.0
#   - Contains NaNs: No
#   - Column 'total_il_high_credit_limit' is within float32 range and can be safely cast to float32.
#   - Column 'total_il_high_credit_limit' has been cast to float32.
#
# Analyzing column 'revol_bal_joint':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'revol_bal_joint' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_fico_range_low':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_fico_range_low' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_fico_range_high':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_fico_range_high' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_earliest_cr_line':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_earliest_cr_line' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_inq_last_6mths':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_inq_last_6mths' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_mort_acc':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_mort_acc' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_open_acc':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_open_acc' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_revol_util':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_revol_util' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_open_act_il':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_open_act_il' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_num_rev_accts':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_num_rev_accts' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_chargeoff_within_12_mths':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_chargeoff_within_12_mths' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_collections_12_mths_ex_med':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_collections_12_mths_ex_med' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'sec_app_mths_since_last_major_derog':
#   - Min value: nan
#   - Max value: nan
#   - Contains NaNs: Yes
#   - Column 'sec_app_mths_since_last_major_derog' has values outside the float32 range. Conversion to float32 is not safe.
#
# Analyzing column 'deferral_term':
#   - Min value: 3.0
#   - Max value: 3.0
#   - Contains NaNs: Yes
#   - Column 'deferral_term' is within float32 range and can be safely cast to float32.
#   - Column 'deferral_term' has been cast to float32.
#
# Analyzing column 'hardship_amount':
#   - Min value: 1.47
#   - Max value: 382.34
#   - Contains NaNs: Yes
#   - Column 'hardship_amount' is within float32 range and can be safely cast to float32.
#   - Column 'hardship_amount' has been cast to float32.
#
# Analyzing column 'hardship_length':
#   - Min value: 3.0
#   - Max value: 3.0
#   - Contains NaNs: Yes
#   - Column 'hardship_length' is within float32 range and can be safely cast to float32.
#   - Column 'hardship_length' has been cast to float32.
#
# Analyzing column 'hardship_dpd':
#   - Min value: 0.0
#   - Max value: 32.0
#   - Contains NaNs: Yes
#   - Column 'hardship_dpd' is within float32 range and can be safely cast to float32.
#   - Column 'hardship_dpd' has been cast to float32.
#
# Analyzing column 'orig_projected_additional_accrued_interest':
#   - Min value: 4.41
#   - Max value: 1147.02
#   - Contains NaNs: Yes
#   - Column 'orig_projected_additional_accrued_interest' is within float32 range and can be safely cast to float32.
#   - Column 'orig_projected_additional_accrued_interest' has been cast to float32.
#
# Analyzing column 'hardship_payoff_balance_amount':
#   - Min value: 174.15
#   - Max value: 21750.75
#   - Contains NaNs: Yes
#   - Column 'hardship_payoff_balance_amount' is within float32 range and can be safely cast to float32.
#   - Column 'hardship_payoff_balance_amount' has been cast to float32.
#
# Analyzing column 'hardship_last_payment_amount':
#   - Min value: 0.04
#   - Max value: 757.42
#   - Contains NaNs: Yes
#   - Column 'hardship_last_payment_amount' is within float32 range and can be safely cast to float32.
#   - Column 'hardship_last_payment_amount' has been cast to float32.
#
# Analyzing column 'settlement_amount':
#   - Min value: 233.16
#   - Max value: 26751.74
#   - Contains NaNs: Yes
#   - Column 'settlement_amount' is within float32 range and can be safely cast to float32.
#   - Column 'settlement_amount' has been cast to float32.
#
# Analyzing column 'settlement_percentage':
#   - Min value: 0.55
#   - Max value: 100.0
#   - Contains NaNs: Yes
#   - Column 'settlement_percentage' is within float32 range and can be safely cast to float32.
#   - Column 'settlement_percentage' has been cast to float32.
#
# Analyzing column 'settlement_term':
#   - Min value: 0.0
#   - Max value: 36.0
#   - Contains NaNs: Yes
#   - Column 'settlement_term' is within float32 range and can be safely cast to float32.
#   - Column 'settlement_term' has been cast to float32.

# %%
object_columns = [col for col in loans.columns if loans[col].dtype == 'O']

loans[object_columns]

for i in object_columns:
    if 'flag' in i:
        print(i)

loans[['hardship_flag', 'debt_settlement_flag']]
# Out:
# hardship_flag
# debt_settlement_flag
# debt_settlement_flag_date
#       hardship_flag debt_settlement_flag
# 0                 N                    N
# 1                 N                    N
# 2                 N                    N
# 3                 N                    N
# 4                 N                    N
# ...             ...                  ...
# 99995             N                    N
# 99996             N                    N
# 99997             N                    N
# 99998             N                    N
# 99999             N                    N
#
# [100000 rows x 2 columns]

# %%
bool_cols = ['hardship_flag', 'debt_settlement_flag']

for col in bool_cols:
    loans[col] = loans[col].apply(lambda x: True if x == 'Y' else (False if x == 'N' else None)).astype('boolean')

#igual encontré que pymnt_plan esta en el formato de y y n
loans['pymnt_plan'] = loans['pymnt_plan'].apply(lambda x: True if x == 'Y' else (False if x == 'N' else None)).astype('boolean')

# %%
nan_only_columns = [col for col in loans.columns if loans[col].isna().all()]
nan_only_columns

loans[nan_only_columns]
# Out:
#        member_id  pymnt_plan  annual_inc_joint  dti_joint  \
# 0            NaN        <NA>               NaN        NaN
# 1            NaN        <NA>               NaN        NaN
# 2            NaN        <NA>               NaN        NaN
# 3            NaN        <NA>               NaN        NaN
# 4            NaN        <NA>               NaN        NaN
# ...          ...         ...               ...        ...
# 99995        NaN        <NA>               NaN        NaN
# 99996        NaN        <NA>               NaN        NaN
# 99997        NaN        <NA>               NaN        NaN
# 99998        NaN        <NA>               NaN        NaN
# 99999        NaN        <NA>               NaN        NaN
#
#        verification_status_joint  open_acc_6m  open_act_il  open_il_12m  \
# 0                            NaN          NaN          NaN          NaN
# 1                            NaN          NaN          NaN          NaN
# 2                            NaN          NaN          NaN          NaN
# 3                            NaN          NaN          NaN          NaN
# 4                            NaN          NaN          NaN          NaN
# ...                          ...          ...          ...          ...
# 99995                        NaN          NaN          NaN          NaN
# 99996                        NaN          NaN          NaN          NaN
# 99997                        NaN          NaN          NaN          NaN
# 99998                        NaN          NaN          NaN          NaN
# 99999                        NaN          NaN          NaN          NaN
#
#        open_il_24m  mths_since_rcnt_il  ...  sec_app_earliest_cr_line  \
# 0              NaN                 NaN  ...                       NaN
# 1              NaN                 NaN  ...                       NaN
# 2              NaN                 NaN  ...                       NaN
# 3              NaN                 NaN  ...                       NaN
# 4              NaN                 NaN  ...                       NaN
# ...            ...                 ...  ...                       ...
# 99995          NaN                 NaN  ...                       NaN
# 99996          NaN                 NaN  ...                       NaN
# 99997          NaN                 NaN  ...                       NaN
# 99998          NaN                 NaN  ...                       NaN
# 99999          NaN                 NaN  ...                       NaN
#
#        sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                         NaN               NaN               NaN
# 1                         NaN               NaN               NaN
# 2                         NaN               NaN               NaN
# 3                         NaN               NaN               NaN
# 4                         NaN               NaN               NaN
# ...                       ...               ...               ...
# 99995                     NaN               NaN               NaN
# 99996                     NaN               NaN               NaN
# 99997                     NaN               NaN               NaN
# 99998                     NaN               NaN               NaN
# 99999                     NaN               NaN               NaN
#
#        sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN                  NaN                    NaN
# ...                   ...                  ...                    ...
# 99995                 NaN                  NaN                    NaN
# 99996                 NaN                  NaN                    NaN
# 99997                 NaN                  NaN                    NaN
# 99998                 NaN                  NaN                    NaN
# 99999                 NaN                  NaN                    NaN
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ...                                 ...                                 ...
# 99995                               NaN                                 NaN
# 99996                               NaN                                 NaN
# 99997                               NaN                                 NaN
# 99998                               NaN                                 NaN
# 99999                               NaN                                 NaN
#
#        sec_app_mths_since_last_major_derog
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 99995                                  NaN
# 99996                                  NaN
# 99997                                  NaN
# 99998                                  NaN
# 99999                                  NaN
#
# [100000 rows x 32 columns]

# %%
#cambiar grades y subgrades a categorical data porque son categorias
loans['grade'] = loans['grade'].astype('category')
loans['sub_grade'] = loans['sub_grade'].astype('category')

#de igual manera home_ownership, loan_status, verification_status, purpose, initial_list_status, policy_code, application_type, hardship_status, hardship_type
#porque tienen valores repetidos
loans['home_ownership'] = loans['home_ownership'].astype('category')
loans['loan_status'] = loans['loan_status'].astype('category')
loans['verification_status'] = loans['verification_status'].astype('category')
loans['purpose'] = loans['purpose'].astype('category') 
loans['initial_list_status'] = loans['initial_list_status'].astype('category')
loans['policy_code'] = loans['policy_code'].astype('category')
loans['application_type'] = loans['application_type'].astype('category')
loans['hardship_status'] = loans['hardship_status'].astype('category')
loans['hardship_type'] = loans['hardship_type'].astype('category')

#Cambiamos
loans['desc'] = loans['desc'].astype(str) 
loans['title'] = loans['title'].astype(str)
loans['zip_code'] = loans['zip_code'].astype(str)  
loans['addr_state'] = loans['addr_state'].astype(str)

# %%
# Convert columns to datetime type
date_columns = [
    'issue_d', 'earliest_cr_line', 'last_pymnt_d', 'next_pymnt_d',
    'last_credit_pull_d', 'hardship_start_date', 'hardship_end_date',
    'payment_plan_start_date', 'debt_settlement_flag_date', 'settlement_date'
]
for col in date_columns:
    loans[col] = pd.to_datetime(loans[col], errors='coerce')
# Out:
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')
# /tmp/ipykernel_7375/3952976714.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans[col] = pd.to_datetime(loans[col], errors='coerce')

# %%
loans['desc']
# Out:
# 0        nan
# 1        nan
# 2        nan
# 3        nan
# 4        nan
#         ...
# 99995    nan
# 99996    nan
# 99997    nan
# 99998    nan
# 99999    nan
# Name: desc, Length: 100000, dtype: object

# %% [markdown]
# ## Manejo de NaNs o missings

# %% [markdown]
# Maneja los datos de tipos missing. Elije una estrategia adecuada dependiendo del tipo de dato que le asignaste a la columna.

# %% [markdown]
# Crea codigo para **guardar** y **cargar** un archivo JSON en el que se guarde la `estrategia` y `valor` que utilizaste para **imputar**. Por ejemplo: Si hay una columna que se llama `columna 3` y utilizaste la estrategia de imputacion de media, y existe otra llamada `columna 4` y  elegiste la palabra 'missing' el JSON debera contener:
#
#  `{'columna 3':{'estrategia':'mean', 'valor':3.4}, 'columna 4':{'estrategia':'identificador', 'valor':'missing'}}`
#
#  De tal manera que para cada columna que tenga un metodo de imputacion apunte a otro diccionario donde el **key** `estrategia` describa de manera sencilla el metodo, y el **key** `valor` el valor usado. En general:
#  `{'nombre de la columna':{'estrategia':'descripcion de estrategia', 'valor':'valor utilizado'}}`.
#
#
# De utilizar mas de un metodo puedes anidarlos en una lista
#   `[{...},{...}]`.
#
# Incluso si la columna utilizada no sufrio imputacion, es necesario que la agregues al JSON.
#
# La idea es que cualquier otra persona pueda cargar el el archivo JSON con tu funcion, entender que hiciste y replicarlo facilmente. No existe solo una respuesta correcta, pero tendras que justificar y explicar tus deciciones.

# %% [markdown]
# ### Imputacion

# %%
import pandas as pd
#primero quitamos todas las columnas que solo contengan Nan porque son columnas que no aportan nada de información y ocupan espacio
def drop_nan_only_columns(df):
    """
    Drops columns that contain only NaN values.

    Parameters:
    df (pd.DataFrame): The DataFrame from which to drop NaN-only columns.

    Returns:
    pd.DataFrame: A DataFrame with NaN-only columns removed.
    """
    # Drop columns where all values are NaN
    df_cleaned = df.dropna(axis=1, how='all')
    return df_cleaned

# Example usage
# Assuming `loans` is your DataFrame
loans_cleaned = drop_nan_only_columns(loans)

# %%
import pandas as pd
import numpy as np
import json

# Function to handle numeric column imputation
def imputar_numerico(df, column):
    # Use mean or median based on skewness
    if abs(df[column].skew()) < 1:
        value = df[column].mean()
        strategy = 'mean'
    else:
        value = df[column].median()
        strategy = 'median'
    df[column].fillna(value)
    return {"columna":column,"estrategia": strategy, "valor": value}

# %%
def imputar_categorico(df, column):
    # Use a placeholder string for missing values
    value = "missing"
    df[column].fillna(value)
    return { "estrategia": "identificador", "valor": value}

# %%
# Function to handle date column imputation
def imputar_fecha(df, column):
    # Use a placeholder date for missing values
    value = pd.Timestamp("1900-01-01")
    df[column].fillna(value)
    return {"estrategia": "placeholder_date", "valor": str(value)}

# %%
# Function to handle boolean column imputation
def imputar_booleano(df, column):
    # Use False as the default for missing values
    value = False
    df[column].fillna(value)
    return {"estrategia": "default_bool", "valor": value}

# %%
# Main function to apply imputations based on data type
def imputar_valores(df):
    imputation_strategies = {}
    for column in df.columns:
        if df[column].isna().sum() > 0:
            print("woo")
            if pd.api.types.is_numeric_dtype(df[column]):
                imputation_strategies[column] = imputar_numerico(df, column)
            elif pd.api.types.is_object_dtype(df[column]):
                imputation_strategies[column] = imputar_categorico(df, column)
            elif pd.api.types.is_datetime64_any_dtype(df[column]):
                imputation_strategies[column] = imputar_fecha(df, column)
            elif pd.api.types.is_bool_dtype(df[column]):
                imputation_strategies[column] = imputar_booleano(df, column)
        else:
            imputation_strategies[column] = {"estrategia": "sin_imputacion", "valor": None}
    return imputation_strategies

# %%
explanation_strategies = {
    "mean": "Replaces NaN values with the mean of the column for balanced data.",
    "median": "Replaces NaN values with the median of the column for skewed data.",
    "identificador": "Replaces NaN values in categorical columns with a placeholder like 'missing'.",
    "placeholder_date": "Replaces NaN values in date columns with a default date (e.g., '1900-01-01').",
    "default_bool": "Replaces NaN values in boolean columns with a default False value.",
    "sin_imputacion": "Indicates no imputation was needed because no NaN values were present."
}

# %%
imputation_strategies = imputar_valores(loans_cleaned)
# Out:
# woo
# woo

# %%
imputation_strategies
# Out:
# {'Unnamed: 0': {'estrategia': 'sin_imputacion', 'valor': None},
#  'id': {'estrategia': 'sin_imputacion', 'valor': None},
#  'loan_amnt': {'estrategia': 'sin_imputacion', 'valor': None},
#  'funded_amnt': {'estrategia': 'sin_imputacion', 'valor': None},
#  'funded_amnt_inv': {'estrategia': 'sin_imputacion', 'valor': None},
#  'term': {'estrategia': 'sin_imputacion', 'valor': None},
#  'int_rate': {'estrategia': 'sin_imputacion', 'valor': None},
#  'installment': {'estrategia': 'sin_imputacion', 'valor': None},
#  'grade': {'estrategia': 'sin_imputacion', 'valor': None},
#  'sub_grade': {'estrategia': 'sin_imputacion', 'valor': None},
#  'emp_title': {'estrategia': 'sin_imputacion', 'valor': None},
#  'emp_length': {'estrategia': 'sin_imputacion', 'valor': None},
#  'home_ownership': {'estrategia': 'sin_imputacion', 'valor': None},
#  'annual_inc': {'estrategia': 'sin_imputacion', 'valor': None},
#  'verification_status': {'estrategia': 'sin_imputacion', 'valor': None},
#  'issue_d': {'estrategia': 'sin_imputacion', 'valor': None},
#  'loan_status': {'estrategia': 'sin_imputacion', 'valor': None},
#  'desc': {'estrategia': 'sin_imputacion', 'valor': None},
#  'purpose': {'estrategia': 'sin_imputacion', 'valor': None},
#  'title': {'estrategia': 'sin_imputacion', 'valor': None},
#  'zip_code': {'estrategia': 'sin_imputacion', 'valor': None},
#  'addr_state': {'estrategia': 'sin_imputacion', 'valor': None},
#  'dti': {'estrategia': 'sin_imputacion', 'valor': None},
#  'delinq_2yrs': {'estrategia': 'sin_imputacion', 'valor': None},
#  'earliest_cr_line': {'estrategia': 'sin_imputacion', 'valor': None},
#  'fico_range_low': {'estrategia': 'sin_imputacion', 'valor': None},
#  'fico_range_high': {'estrategia': 'sin_imputacion', 'valor': None},
#  'inq_last_6mths': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mths_since_last_delinq': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mths_since_last_record': {'estrategia': 'sin_imputacion', 'valor': None},
#  'open_acc': {'estrategia': 'sin_imputacion', 'valor': None},
#  'pub_rec': {'estrategia': 'sin_imputacion', 'valor': None},
#  'revol_bal': {'estrategia': 'sin_imputacion', 'valor': None},
#  'revol_util': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_acc': {'estrategia': 'sin_imputacion', 'valor': None},
#  'initial_list_status': {'estrategia': 'sin_imputacion', 'valor': None},
#  'out_prncp': {'estrategia': 'sin_imputacion', 'valor': None},
#  'out_prncp_inv': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_pymnt': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_pymnt_inv': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_rec_prncp': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_rec_int': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_rec_late_fee': {'estrategia': 'sin_imputacion', 'valor': None},
#  'recoveries': {'estrategia': 'sin_imputacion', 'valor': None},
#  'collection_recovery_fee': {'estrategia': 'sin_imputacion', 'valor': None},
#  'last_pymnt_d': {'estrategia': 'sin_imputacion', 'valor': None},
#  'last_pymnt_amnt': {'estrategia': 'sin_imputacion', 'valor': None},
#  'next_pymnt_d': {'estrategia': 'sin_imputacion', 'valor': None},
#  'last_credit_pull_d': {'estrategia': 'sin_imputacion', 'valor': None},
#  'last_fico_range_high': {'estrategia': 'sin_imputacion', 'valor': None},
#  'last_fico_range_low': {'estrategia': 'sin_imputacion', 'valor': None},
#  'collections_12_mths_ex_med': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mths_since_last_major_derog': {'estrategia': 'sin_imputacion',
#   'valor': None},
#  'policy_code': {'estrategia': 'sin_imputacion', 'valor': None},
#  'application_type': {'estrategia': 'sin_imputacion', 'valor': None},
#  'acc_now_delinq': {'estrategia': 'sin_imputacion', 'valor': None},
#  'tot_coll_amt': {'estrategia': 'sin_imputacion', 'valor': None},
#  'tot_cur_bal': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_rev_hi_lim': {'estrategia': 'sin_imputacion', 'valor': None},
#  'acc_open_past_24mths': {'estrategia': 'sin_imputacion', 'valor': None},
#  'avg_cur_bal': {'estrategia': 'sin_imputacion', 'valor': None},
#  'bc_open_to_buy': {'estrategia': 'sin_imputacion', 'valor': None},
#  'bc_util': {'estrategia': 'sin_imputacion', 'valor': None},
#  'chargeoff_within_12_mths': {'estrategia': 'sin_imputacion', 'valor': None},
#  'delinq_amnt': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mo_sin_old_il_acct': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mo_sin_old_rev_tl_op': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mo_sin_rcnt_rev_tl_op': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mo_sin_rcnt_tl': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mort_acc': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mths_since_recent_bc': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mths_since_recent_bc_dlq': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mths_since_recent_inq': {'estrategia': 'sin_imputacion', 'valor': None},
#  'mths_since_recent_revol_delinq': {'estrategia': 'sin_imputacion',
#   'valor': None},
#  'num_accts_ever_120_pd': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_actv_bc_tl': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_actv_rev_tl': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_bc_sats': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_bc_tl': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_il_tl': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_op_rev_tl': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_rev_accts': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_rev_tl_bal_gt_0': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_sats': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_tl_120dpd_2m': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_tl_30dpd': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_tl_90g_dpd_24m': {'estrategia': 'sin_imputacion', 'valor': None},
#  'num_tl_op_past_12m': {'estrategia': 'sin_imputacion', 'valor': None},
#  'pct_tl_nvr_dlq': {'estrategia': 'sin_imputacion', 'valor': None},
#  'percent_bc_gt_75': {'estrategia': 'sin_imputacion', 'valor': None},
#  'pub_rec_bankruptcies': {'estrategia': 'sin_imputacion', 'valor': None},
#  'tax_liens': {'estrategia': 'sin_imputacion', 'valor': None},
#  'tot_hi_cred_lim': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_bal_ex_mort': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_bc_limit': {'estrategia': 'sin_imputacion', 'valor': None},
#  'total_il_high_credit_limit': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_flag': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_reason': {'estrategia': 'sin_imputacion', 'valor': None},
#  'deferral_term': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_amount': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_start_date': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_end_date': {'estrategia': 'sin_imputacion', 'valor': None},
#  'payment_plan_start_date': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_length': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_dpd': {'estrategia': 'sin_imputacion', 'valor': None},
#  'hardship_loan_status': {'estrategia': 'sin_imputacion', 'valor': None},
#  'orig_projected_additional_accrued_interest': {'estrategia': 'sin_imputacion',
#   'valor': None},
#  'hardship_payoff_balance_amount': {'estrategia': 'sin_imputacion',
#   'valor': None},
#  'hardship_last_payment_amount': {'estrategia': 'sin_imputacion',
#   'valor': None},
#  'disbursement_method': {'estrategia': 'sin_imputacion', 'valor': None},
#  'debt_settlement_flag': {'estrategia': 'sin_imputacion', 'valor': None},
#  'debt_settlement_flag_date': {'estrategia': 'sin_imputacion', 'valor': None},
#  'settlement_status': {'estrategia': 'sin_imputacion', 'valor': None},
#  'settlement_date': {'estrategia': 'sin_imputacion', 'valor': None},
#  'settlement_amount': {'estrategia': 'sin_imputacion', 'valor': None},
#  'settlement_percentage': {'estrategia': 'sin_imputacion', 'valor': None},
#  'settlement_term': {'estrategia': 'sin_imputacion', 'valor': None}}

# %% [markdown]
# ### Codigo para salvar y cargar JSONs

# %%
# Save imputation strategies to JSON
with open("imputation_strategies.json", "w") as file:
    json.dump(imputation_strategies, file, indent=4)

# Save strategy explanations to JSON
with open("strategy_explanations.json", "w") as file:
    json.dump(explanation_strategies, file, indent=4)

# %%
def load_json(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# Load the JSON containing imputation strategies for each column
imputation_strategies = load_json("imputation_strategies.json")
print("Imputation Strategies:\n", imputation_strategies)

# Load the JSON containing explanations of each strategy
strategy_explanations = load_json("strategy_explanations.json")
print("\nStrategy Explanations:\n", strategy_explanations)
# Out:
# Imputation Strategies:
#  {'Unnamed: 0': {'estrategia': 'sin_imputacion', 'valor': None}, 'id': {'estrategia': 'sin_imputacion', 'valor': None}, 'loan_amnt': {'estrategia': 'sin_imputacion', 'valor': None}, 'funded_amnt': {'estrategia': 'sin_imputacion', 'valor': None}, 'funded_amnt_inv': {'estrategia': 'sin_imputacion', 'valor': None}, 'term': {'estrategia': 'sin_imputacion', 'valor': None}, 'int_rate': {'estrategia': 'sin_imputacion', 'valor': None}, 'installment': {'estrategia': 'sin_imputacion', 'valor': None}, 'grade': {'estrategia': 'sin_imputacion', 'valor': None}, 'sub_grade': {'estrategia': 'sin_imputacion', 'valor': None}, 'emp_title': {'estrategia': 'sin_imputacion', 'valor': None}, 'emp_length': {'estrategia': 'sin_imputacion', 'valor': None}, 'home_ownership': {'estrategia': 'sin_imputacion', 'valor': None}, 'annual_inc': {'estrategia': 'sin_imputacion', 'valor': None}, 'verification_status': {'estrategia': 'sin_imputacion', 'valor': None}, 'issue_d': {'estrategia': 'sin_imputacion', 'valor': None}, 'loan_status': {'estrategia': 'sin_imputacion', 'valor': None}, 'desc': {'estrategia': 'sin_imputacion', 'valor': None}, 'purpose': {'estrategia': 'sin_imputacion', 'valor': None}, 'title': {'estrategia': 'sin_imputacion', 'valor': None}, 'zip_code': {'estrategia': 'sin_imputacion', 'valor': None}, 'addr_state': {'estrategia': 'sin_imputacion', 'valor': None}, 'dti': {'estrategia': 'sin_imputacion', 'valor': None}, 'delinq_2yrs': {'estrategia': 'sin_imputacion', 'valor': None}, 'earliest_cr_line': {'estrategia': 'sin_imputacion', 'valor': None}, 'fico_range_low': {'estrategia': 'sin_imputacion', 'valor': None}, 'fico_range_high': {'estrategia': 'sin_imputacion', 'valor': None}, 'inq_last_6mths': {'estrategia': 'sin_imputacion', 'valor': None}, 'mths_since_last_delinq': {'estrategia': 'sin_imputacion', 'valor': None}, 'mths_since_last_record': {'estrategia': 'sin_imputacion', 'valor': None}, 'open_acc': {'estrategia': 'sin_imputacion', 'valor': None}, 'pub_rec': {'estrategia': 'sin_imputacion', 'valor': None}, 'revol_bal': {'estrategia': 'sin_imputacion', 'valor': None}, 'revol_util': {'estrategia': 'sin_imputacion', 'valor': None}, 'total_acc': {'estrategia': 'sin_imputacion', 'valor': None}, 'initial_list_status': {'estrategia': 'sin_imputacion', 'valor': None}, 'out_prncp': {'estrategia': 'sin_imputacion', 'valor': None}, 'out_prncp_inv': {'estrategia': 'sin_imputacion', 'valor': None}, 'total_pymnt': {'estrategia': 'sin_imputacion', 'valor': None}, 'total_pymnt_inv': {'estrategia': 'sin_imputacion', 'valor': None}, 'total_rec_prncp': {'estrategia': 'sin_imputacion', 'valor': None}, 'total_rec_int': {'estrategia': 'sin_imputacion', 'valor': None}, 'total_rec_late_fee': {'estrategia': 'sin_imputacion', 'valor': None}, 'recoveries': {'estrategia': 'sin_imputacion', 'valor': None}, 'collection_recovery_fee': {'estrategia': 'sin_imputacion', 'valor': None}, 'last_pymnt_d': {'estrategia': 'sin_imputacion', 'valor': None}, 'last_pymnt_amnt': {'estrategia': 'sin_imputacion', 'valor': None}, 'next_pymnt_d': {'estrategia': 'sin_imputacion', 'valor': None}, 'last_credit_pull_d': {'estrategia': 'sin_imputacion', 'valor': None}, 'last_fico_range_high': {'estrategia': 'sin_imputacion', 'valor': None}, 'last_fico_range_low': {'estrategia': 'sin_imputacion', 'valor': None}, 'collections_12_mths_ex_med': {'estrategia': 'sin_imputacion', 'valor': None}, 'mths_since_last_major_derog': {'estrategia': 'sin_imputacion', 'valor': None}, 'policy_code': {'estrategia': 'sin_imputacion', 'valor': None}, 'application_type': {'estrategia': 'sin_imputacion', 'valor': None}, 'acc_now_delinq': {'estrategia': 'sin_imputacion', 'valor': None}, 'tot_coll_amt': {'estrategia': 'sin_imputacion', 'valor': None}, 'tot_cur_bal': {'estrategia': 'sin_imputacion', 'valor': None}, 'total_rev_hi_lim': {'estrategia': 'sin_imputacion', 'valor': None}, 'acc_open_past_24mths': {'estrategia': 'sin_imputacion', 'valor': None}, 'avg_cur_bal': {'estrategia': 'sin_imputacion', 'valor': None}, ' ...
#
# Strategy Explanations:
#  {'mean': 'Replaces NaN values with the mean of the column for balanced data.', 'median': 'Replaces NaN values with the median of the column for skewed data.', 'identificador': "Replaces NaN values in categorical columns with a placeholder like 'missing'.", 'placeholder_date': "Replaces NaN values in date columns with a default date (e.g., '1900-01-01').", 'default_bool': 'Replaces NaN values in boolean columns with a default False value.', 'sin_imputacion': 'Indicates no imputation was needed because no NaN values were present.'}
